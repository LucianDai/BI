# %%
import csv
import py2neo
from py2neo import Graph,Node,Relationship,NodeMatcher

g=Graph('http://localhost:7474/',user='neo4j',password='000119djh.',name='neo4j')

# %%
with open('E:/Jupyter Notebook/产业链CSV表utf-8/xinnengyuan.csv','r',encoding='utf-8') as f:
    reader = csv.reader(x.replace('\0', '') for x in f)
    for item in reader:
        if reader.line_num==1:
            continue
        print("当前行数:",reader.line_num,"当前内容:",item)
        start_node=Node("Product",name=item[0])
        end_node=Node("Product",name=item[1])
        relation=Relationship(start_node,item[3],end_node)
        #g.create(start_node)
        #g.create(end_node)
        #g.create(relation)
        g.merge(start_node,"Product","name")
        g.merge(end_node,"Product","name")   
        g.merge(relation,"Product","name")
# Out:
# 当前行数: 2 当前内容: ['镍矿', '正极材料', 'component', '原材料']
# 当前行数: 3 当前内容: ['钴矿', '正极材料', 'component', '原材料']
# 当前行数: 4 当前内容: ['锂矿', '正极材料', 'component', '原材料']
# 当前行数: 5 当前内容: ['锰矿', '正极材料', 'component', '原材料']
# 当前行数: 6 当前内容: ['碳酸锂', '正极材料', 'component', '原材料']
# 当前行数: 7 当前内容: ['石墨', '负极材料', 'component', '原材料']
# 当前行数: 8 当前内容: ['六氟磷酸锂', '电解液', 'component', '原材料']
# 当前行数: 9 当前内容: ['聚乙烯', '聚丙烯', 'component', '原材料']
# 当前行数: 10 当前内容: ['聚丙烯', '隔膜', 'component', '原材料']
# 当前行数: 11 当前内容: ['锂电设备', '隔膜', 'component', '原材料']
# 当前行数: 12 当前内容: ['正极材料', '电芯与PACK', 'component', '原材料']
# 当前行数: 13 当前内容: ['铝箔', '电芯与PACK', 'component', '原材料']
# 当前行数: 14 当前内容: ['负极材料', '电芯与PACK', 'component', '原材料']
# 当前行数: 15 当前内容: ['电解液', '电芯与PACK', 'component', '原材料']
# 当前行数: 16 当前内容: ['隔膜', '电芯与PACK', 'component', '原材料']
# 当前行数: 17 当前内容: ['铁矿', '硅钢片', 'component', '原材料']
# 当前行数: 18 当前内容: ['稀土', '永磁材料', 'component', '原材料']
# 当前行数: 19 当前内容: ['碳化硅', 'IGBT芯片', 'component', '原材料']

# %%
with open('E:/Jupyter Notebook/产业链CSV表utf-8/zhongduanbujian.csv','r',encoding='utf-8') as f:
    reader = csv.reader(x.replace('\0', '') for x in f)
    for item in reader:
        if reader.line_num==1:
            continue
        print("当前行数:",reader.line_num,"当前内容:",item)
        start_node=Node("Product",name=item[0])
        end_node=Node("Terminal",name=item[1])
        relation=Relationship(start_node,item[3],end_node)
        #g.create(start_node)
        #g.create(end_node)
        #g.create(relation)
        g.merge(start_node,"Product","name")
        g.merge(end_node,"Terminal","name")   
        g.merge(relation,"Product","name")
# Out:
# 当前行数: 2 当前内容: ['电芯与PACK', '动力电池组', 'component', '原材料']
# 当前行数: 3 当前内容: ['隔膜', '动力电池组', 'component', '原材料']
# 当前行数: 4 当前内容: ['电池结构件', '动力电池组', 'component', '原材料']
# 当前行数: 5 当前内容: ['BMS', '动力电池组', 'component', '原材料']
# 当前行数: 6 当前内容: ['电子控制系统', '汽车电子', 'component', '原材料']
# 当前行数: 7 当前内容: ['车载电子装置', '汽车电子', 'component', '原材料']
# 当前行数: 8 当前内容: ['硅钢片', '电机', 'component', '原材料']
# 当前行数: 9 当前内容: ['永磁材料', '电机', 'component', '原材料']
# 当前行数: 10 当前内容: ['PCB板', '电控', 'component', '原材料']
# 当前行数: 11 当前内容: ['IGBT芯片', '电控', 'component', '原材料']
# 当前行数: 12 当前内容: ['汽车热管理', '整车制造', 'component', '原材料']
# 当前行数: 13 当前内容: ['水箱', '整车制造', 'component', '原材料']
# 当前行数: 14 当前内容: ['进气格栅', '整车制造', 'component', '原材料']
# 当前行数: 15 当前内容: ['后视镜', '整车制造', 'component', '原材料']
# 当前行数: 16 当前内容: ['车窗玻璃', '整车制造', 'component', '原材料']
# 当前行数: 17 当前内容: ['安全气囊', '整车制造', 'component', '原材料']
# 当前行数: 18 当前内容: ['脚垫', '整车制造', 'component', '原材料']
# 当前行数: 19 当前内容: ['方向盘', '整车制造', 'component', '原材料']
# 当前行数: 20 当前内容: ['主地毯', '整车制造', 'component', '原材料']
# 当前行数: 21 当前内容: ['保险杠', '整车制造', 'component', '原材料']
# 当前行数: 22 当前内容: ['车灯', '整车制造', 'component', '原材料']
# 当前行数: 23 当前内容: ['座椅', '整车制造', 'component', '原材料']
# 当前行数: 24 当前内容: ['仪表盘', '整车制造', 'component', '原材料']
# 当前行数: 25 当前内容: ['车身', '整车制造', 'component', '原材料']
# 当前行数: 26 当前内容: ['车饰板', '整车制造', 'component', '原材料']
# 当前行数: 27 当前内容: ['底盘', '整车制造', 'component', '原材料']
# 当前行数: 28 当前内容: ['轮胎', '整车制造', 'component', '原材料']
# 当前行数: 29 当前内容: ['车桥', '整车制造', 'component', '原材料']
# 当前行数: 30 当前内容: ['刹车片', '整车制造', 'component', '原材料']
# 当前行数: 31 当前内容: ['传动轴', '整车制造', 'component', '原材料']
# 当前行数: 32 当前内容: ['减震器', '整车制造', 'component', '原材料']

# %%
with open('E:/Jupyter Notebook/产业链CSV表utf-8/peihe.csv','r',encoding='utf-8') as f:
    reader = csv.reader(x.replace('\0', '') for x in f)
    for item in reader:
        if reader.line_num==1:
            continue
        print("当前行数:",reader.line_num,"当前内容:",item)
        start_node=Node("Terminal",name=item[0])
        end_node=Node("Terminal",name=item[1])
        relation=Relationship(start_node,item[3],end_node)
        #g.create(start_node)
        #g.create(end_node)
        #g.create(relation)
        g.merge(start_node,"Terminal","name")
        g.merge(end_node,"Terminal","name")   
        g.merge(relation,"Terminal","name")
# Out:
# 当前行数: 2 当前内容: ['动力电池组', '汽车电子', 'coordinate', '能源-控制']
# 当前行数: 3 当前内容: ['电机', '电控', 'coordinate', '动力-控制']
# 当前行数: 4 当前内容: ['汽车电子', '整车制造', 'coordinate', '控制-制造']
# 当前行数: 5 当前内容: ['电控', '整车制造', 'coordinate', '控制-制造']

# %%
with open('E:/Jupyter Notebook/产业链CSV表utf-8/gongsi-product.csv','r',encoding='utf-8') as f:
    reader = csv.reader(x.replace('\0', '') for x in f)
    for item in reader:
        if reader.line_num==1:
            continue
        print("当前行数:",reader.line_num,"当前内容:",item)
        start_node=Node("Corporation",name=item[0],product=item[3])
        end_node=Node("Product",name=item[1],)
        relation=Relationship(start_node,item[2],end_node)
        #g.create(start_node)
        #g.create(end_node)
        #g.create(relation)
        g.merge(start_node,"Corporation","name")
        g.merge(end_node,"Product","name")   
        g.merge(relation,"Corporation","name")
# Out:
# 当前行数: 2 当前内容: ['罕王实业集团有限公司', '镍矿', '生产', '镍矿']
# 当前行数: 3 当前内容: ['金川集团股份有限公司', '镍矿', '生产', '镍矿']
# 当前行数: 4 当前内容: ['浙江华友钴业股份有限公司', '钴矿', '生产', '钴矿']
# 当前行数: 5 当前内容: ['江苏容汇通用锂业股份有限公司', '锂矿', '生产', '锂矿']
# 当前行数: 6 当前内容: ['江西赣锋锂业集团股份有限公司', '锂矿', '生产', '锂矿']
# 当前行数: 7 当前内容: ['天齐锂业股份有限公司', '锂矿', '生产', '锂矿']
# 当前行数: 8 当前内容: ['湘潭电化科技股份有限公司', '锰矿', '生产', '锰矿']
# 当前行数: 9 当前内容: ['西部黄金股份有限公司', '锰矿', '生产', '锰矿']
# 当前行数: 10 当前内容: ['安徽红军红农业发展有限公司', '锰矿', '生产', '锰矿']
# 当前行数: 11 当前内容: ['焦作市东星炭电极有限公司', '石墨', '生产', '石墨']
# 当前行数: 12 当前内容: ['大同新成新材料股份有限公司', '石墨', '生产', '石墨']
# 当前行数: 13 当前内容: ['济南万方炭素有限责任公司', '石墨', '生产', '石墨']
# 当前行数: 14 当前内容: ['多氟多新材料股份有限公司', '六氟磷酸锂', '生产', '六氟磷酸锂']
# 当前行数: 15 当前内容: ['江西东鹏新材料有限责任公司', '六氟磷酸锂', '生产', '六氟磷酸锂']
# 当前行数: 16 当前内容: ['天际新能源科技股份有限公司', '六氟磷酸锂', '生产', '六氟磷酸锂']
# 当前行数: 17 当前内容: ['中材科技股份有限公司', '聚乙烯', '生产', '聚乙烯']
# 当前行数: 18 当前内容: ['天茂实业集团股份有限公司', '聚乙烯', '生产', '聚乙烯']
# 当前行数: 19 当前内容: ['北京昊华能源股份有限公司', '聚乙烯', '生产', '聚乙烯']
# 当前行数: 20 当前内容: ['航天彩虹无人机股份有限公司', '聚丙烯', '生产', '聚丙烯']
# 当前行数: 21 当前内容: ['顾地科技股份有限公司', '聚丙烯', '生产', '聚丙烯']
# 当前行数: 22 当前内容: ['宁夏宝丰能源集团股份有限公司', '聚丙烯', '生产', '聚丙烯']
# 当前行数: 23 当前内容: ['惠州亿纬锂能股份有限公司', '锂电设备', '生产', '锂电设备']
# 当前行数: 24 当前内容: ['江苏亿多力新能源科技有限公司', '锂电设备', '生产', '锂电设备']
# 当前行数: 25 当前内容: ['江苏广义牵引技术研究所有限公司', '锂电设备', '生产', '锂电设备']
# 当前行数: 26 当前内容: ['北京当升材料科技股份有限公司', '正极材料', '生产', '正极材料']
# 当前行数: 27 当前内容: ['湖南瑞翔新材料股份有限公司', '正极材料', '生产', '正极材料']
# 当前行数: 28 当前内容: ['惠州比亚迪电池有限公司', '正极材料', '生产', '正极材料']
# 当前行数: 29 当前内容: ['诺德新材料股份有限公司', '铝箔', '生产', '铝箔']
# 当前行数: 30 当前内容: ['广东超华科技股份有限公司', '铝箔', '生产', '铝箔']
# 当前行数: 31 当前内容: ['广东嘉元科技股份有限公司', '铝箔', '生产', '铝箔']
# 当前行数: 32 当前内容: ['江西紫宸科技有限公司', '负极材料', '生产', '负极材料']
# 当前行数: 33 当前内容: ['上海杉杉科技有限公司', '负极材料', '生产', '负极材料']
# 当前行数: 34 当前内容: ['深圳市斯诺实业发展有限公司', '负极材料', '生产', '负极材料']
# 当前行数: 35 当前内容: ['江苏国泰国际集团股份有限公司', '电解液', '生产', '电解液']
# 当前行数: 36 当前内容: ['东莞市杉杉电池材料有限公司', '电解液', '生产', '电解液']
# 当前行数: 37 当前内容: ['湖州杉杉新能源科技有限公司', '电解液', '生产', '电解液']
# 当前行数: 38 当前内容: ['深圳市星源材质科技股份有限公司', '隔膜', '生产', '隔膜']
# 当前行数: 39 当前内容: ['河南义腾新能源科技有限公司', '隔膜', '生产', '隔膜']
# 当前行数: 40 当前内容: ['沧州明珠塑料股份有限公司', '隔膜', '生产', '隔膜']
# 当前行数: 41 当前内容: ['海南矿业股份有限公司', '铁矿', '生产', '铁矿']
# 当前行数: 42 当前内容: ['内蒙古大中矿业股份有限公司', '铁矿', '生产', '铁矿']
# 当前行数: 43 当前内容: ['山东金岭矿业股份有限公司', '铁矿', '生产', '铁矿']
# 当前行数: 44 当前内容: ['中国南方稀土集团有限公司', '稀土', '生产', '稀土']
# 当前行数: 45 当前内容: ['厦门钨业股份有限公司', '稀土', '生产', '稀土']
# 当前行数: 46 当前内容: ['广东省稀土产业集团有限公司', '稀土', '生产', '稀土']
# 当前行数: 47 当前内容: ['浙江零跑科技股份有限公司', '碳化硅', '生产', '碳化硅']
# 当前行数: 48 当前内容: ['南京江智科技有限公司', '碳化硅', '生产', '碳化硅']
# 当前行数: 49 当前内容: ['连云港亮晶新材料科技有限公司', '碳化硅', '生产', '碳化硅']
# 当前行数: 50 当前内容: ['孚能集团有限公司', '电芯与PACK', '生产', '电芯与PACK']
# 当前行数: 51 当前内容: ['国轩高科股份有限公司', '电芯与PACK', '生产', '电芯与PACK']
# 当前行数: 52 当前内容: ['北京普莱德新材料有限公司', '电芯与PACK', '生产', '电芯与PACK']
# 当前行数: 53 当前内容: ['航天科技控股集团股份有限公司', '电池结构件', '生产', '电池结构件']
# 当前行数: 54 当前内容: ['南京聚隆科技股份有限公司', '电池结构件', '生产', '电池结构件']
# 当前行数: 55 当前内容: ['江苏银河电子股份有限公司', '电池结构件', '生产', '电池结构件']
# 当前行数: 56 当前内容: ['福建星云电子股份有限公司', 'BMS', '生产', 'BMS']
# 当前行数: 57 当前内容: ['无锡顺达智能自动化工程股份有限公司', 'BMS', '生产', 'BMS']
# 当前行数: 58 当前内容: ['福建易动力电子科技股份有限公司', 'BMS', '生产', 'BMS']
# 当前行数: 59 当前内容: ['联合汽车电子有限公司', '电子控制系统', '生产', '电子控制系统']
# 当前行数: 60 当前内容: ['广东好帮手电子科技股份有限公司', '电子控制系统', '生产', '电子控制系统']
# 当前行数: 61 当前内容: ['天津市俊天成科技发展有限公司', '电子控制系统', '生产', '电子控制系统']
# 当前行数: 62 当前内容: ['浙江世宝股份有限公司', '车载电子装置', '生产', '车载电子装置']
# 当前行数: 63 当前内容: ['厦门雅迅网络股份有限公司', '车载电子装置', '生产', '车载电子装置']
# 当前行数: 64 当前内容: ['秦川机床工具集团股份公司', '硅钢片', '生产', '硅钢片']
# 当前行数: 65 当前内容: ['山西太钢不锈钢股份有限公司', '硅钢片', '生产', '硅钢片']
# 当前行数: 66 当前内容: ['苏州范斯特机械科技有限公司', '永磁材料', '生产', '永磁材料']
# 当前行数: 67 当前内容: ['成都新柯力化工科技有限公司', '永磁材料', '生产', '永磁材料']
# 当前行数: 68 当前内容: ['深圳市良辉科技有限公司', 'PCB板', '生产', 'PCB板']
# 当前行数: 69 当前内容: ['上海鹰峰电子科技股份有限公司', 'PCB板', '生产', 'PCB板']
# 当前行数: 70 当前内容: ['常州固堡电子有限公司', 'PCB板', '生产', 'PCB板']
# 当前行数: 71 当前内容: ['中国中车股份有限公司', 'IGBT芯片', '生产', 'IGBT芯片']
# 当前行数: 72 当前内容: ['三菱商事（中国）有限公司', 'IGBT芯片', '生产', 'IGBT芯片']
# 当前行数: 73 当前内容: ['东芝（中国）有限公司', 'IGBT芯片', '生产', 'IGBT芯片']
# 当前行数: 74 当前内容: ['浙江创新汽车空调有限公司', '汽车热管理', '生产', '汽车热管理']
# 当前行数: 75 当前内容: ['浙江联星机械股份有限公司', '汽车热管理', '生产', '汽车热管理']
# 当前行数: 76 当前内容: ['江苏晨宇科技有限公司', '汽车热管理', '生产', '汽车热管理']
# 当前行数: 77 当前内容: ['张家港市金帆箱柜有限公司', '水箱', '生产', '水箱']
# 当前行数: 78 当前内容: ['徐州洁驰环保科技有限公司', '水箱', '生产', '水箱']
# 当前行数: 79 当前内容: ['深圳纽斯声学系统有限公司', '水箱', '生产', '水箱']
# 当前行数: 80 当前内容: ['江阴道达汽车饰件有限公司', '进气格栅', '生产', '进气格栅']
# 当前行数: 81 当前内容: ['广州敏惠汽车零部件有限公司', '进气格栅', '生产', '进气格栅']
# 当前行数: 82 当前内容: ['法雷奥汽车空调湖北有限公司', '进气格栅', '生产', '进气格栅']
# 当前行数: 83 当前内容: ['上海龙创汽车设计股份有限公司', '后视镜', '生产', '后视镜']
# 当前行数: 84 当前内容: ['爱柯迪股份有限公司', '后视镜', '生产', '后视镜']
# 当前行数: 85 当前内容: ['湖北金农丰实业有限公司', '后视镜', '生产', '后视镜']
# 当前行数: 86 当前内容: ['珠海华尚汽车玻璃工业有限公司', '车窗玻璃', '生产', '车窗玻璃']
# 当前行数: 87 当前内容: ['江苏皮尔金顿耀皮玻璃有限公司', '车窗玻璃', '生产', '车窗玻璃']
# 当前行数: 88 当前内容: ['北京可隆汽车部件有限公司', '安全气囊', '生产', '安全气囊']
# 当前行数: 89 当前内容: ['东丽（中国）投资有限公司', '安全气囊', '生产', '安全气囊']
# 当前行数: 90 当前内容: ['东洋纺（上海）投资有限公司', '安全气囊', '生产', '安全气囊']
# 当前行数: 91 当前内容: ['宁波朗格世明汽车部件有限公司', '脚垫', '生产', '脚垫']
# 当前行数: 92 当前内容: ['浙江瑞朗特种合金材料有限公司', '脚垫', '生产', '脚垫']
# 当前行数: 93 当前内容: ['3M中国有限公司', '脚垫', '生产', '脚垫']
# 当前行数: 94 当前内容: ['湖北双鸥汽车饰件有限公司', '方向盘', '生产', '方向盘']
# 当前行数: 95 当前内容: ['延锋百利得（上海）汽车安全系统有限公司', '方向盘', '生产', '方向盘']
# 当前行数: 96 当前内容: ['河北鸿泰实业有限公司', '方向盘', '生产', '方向盘']
# 当前行数: 97 当前内容: ['杜邦中国集团有限公司', '主地毯', '生产', '主地毯']
# 当前行数: 98 当前内容: ['阿莫科石油（湖北）有限公司', '主地毯', '生产', '主地毯']
# 当前行数: 99 当前内容: ['长春英利汽车工业股份有限公司', '保险杠', '生产', '保险杠']
# 当前行数: 100 当前内容: ['包头市鹏辉光电科技有限公司', '保险杠', '生产', '保险杠']
# 当前行数: 101 当前内容: ['诸暨市奔宝弹簧有限公司', '保险杠', '生产', '保险杠']
# 当前行数: 102 当前内容: ['天津圣纳科技有限公司', '车灯', '生产', '车灯']
# 当前行数: 103 当前内容: ['常州市常蒸蒸发器有限公司', '车灯', '生产', '车灯']
# 当前行数: 104 当前内容: ['广州立讯检测有限公司', '车灯', '生产', '车灯']
# 当前行数: 105 当前内容: ['常州金源汽车内饰有限公司', '座椅', '生产', '座椅']
# 当前行数: 106 当前内容: ['徐州市恒源电器有限公司', '座椅', '生产', '座椅']
# 当前行数: 107 当前内容: ['南京金龙特种汽车有限公司', '座椅', '生产', '座椅']
# 当前行数: 108 当前内容: ['上海诚品汽车科技有限公司', '仪表盘', '生产', '仪表盘']
# 当前行数: 109 当前内容: ['江苏众众电热科技有限公司', '仪表盘', '生产', '仪表盘']
# 当前行数: 110 当前内容: ['江苏新雷模塑有限公司', '仪表盘', '生产', '仪表盘']
# 当前行数: 111 当前内容: ['广州通达汽车电气股份有限公司', '车身', '生产', '车身']
# 当前行数: 112 当前内容: ['湖南省美程陶瓷科技有限公司', '车身', '生产', '车身']
# 当前行数: 113 当前内容: ['扬州曙光电缆股份有限公司', '车身', '生产', '车身']
# 当前行数: 114 当前内容: ['合肥亿恒智能科技有限公司', '车饰板', '生产', '车饰板']
# 当前行数: 115 当前内容: ['江苏云意电气股份有限公司', '车饰板', '生产', '车饰板']
# 当前行数: 116 当前内容: ['山东铨盛重工有限公司', '车饰板', '生产', '车饰板']
# 当前行数: 117 当前内容: ['中国汽车工程研究院股份有限公司', '底盘', '生产', '底盘']
# 当前行数: 118 当前内容: ['徐州海伦哲专用车辆股份有限公司', '底盘', '生产', '底盘']
# 当前行数: 119 当前内容: ['广州天幸机电设备有限公司', '底盘', '生产', '底盘']
# 当前行数: 120 当前内容: ['大陆马牌轮胎（中国）有限公司', '轮胎', '生产', '轮胎']
# 当前行数: 121 当前内容: ['大连固特异轮胎有限公司', '轮胎', '生产', '轮胎']
# 当前行数: 122 当前内容: ['米其林（中国）投资有限公司', '轮胎', '生产', '轮胎']
# 当前行数: 123 当前内容: ['台州金纳车桥有限公司', '车桥', '生产', '车桥']
# 当前行数: 124 当前内容: ['东风德纳车桥有限公司', '车桥', '生产', '车桥']
# 当前行数: 125 当前内容: ['青岛青特众力车桥有限公司', '车桥', '生产', '车桥']
# 当前行数: 126 当前内容: ['爱德克斯（常州）管理有限公司', '刹车片', '生产', '刹车片']
# 当前行数: 127 当前内容: ['卡莱集团', '刹车片', '生产', '刹车片']
# 当前行数: 128 当前内容: ['湖州德卡斯电子有限公司', '刹车片', '生产', '刹车片']
# 当前行数: 129 当前内容: ['江苏盛安传动股份公司', '传动轴', '生产', '传动轴']
# 当前行数: 130 当前内容: ['安徽航大智能科技有限公司', '传动轴', '生产', '传动轴']
# 当前行数: 131 当前内容: ['山东得普达电机股份有限公司', '减震器', '生产', '减震器']
# 当前行数: 132 当前内容: ['苏州沃泰尔精密模具机械有限公司', '减震器', '生产', '减震器']
# 当前行数: 133 当前内容: ['华晨鑫源重庆汽车有限公司', '减震器', '生产', '减震器']

# %%
with open('E:/Jupyter Notebook/产业链CSV表utf-8/gongsi-terminal.csv','r',encoding='utf-8') as f:
    reader = csv.reader(x.replace('\0', '') for x in f)
    for item in reader:
        if reader.line_num==1:
            continue
        print("当前行数:",reader.line_num,"当前内容:",item)
        start_node=Node("Corporation",name=item[0],product=item[3])
        end_node=Node("Terminal",name=item[1],)
        relation=Relationship(start_node,item[2],end_node)
        #g.create(start_node)
        #g.create(end_node)
        #g.create(relation)
        g.merge(start_node,"Corporation","name")
        g.merge(end_node,"Terminal","name")   
        g.merge(relation,"Corporation","name")
# Out:
# 当前行数: 2 当前内容: ['中国电器科学研究院股份有限公司', '动力电池组', '生产', '动力电池组']
# 当前行数: 3 当前内容: ['江苏远航精密合金科技股份有限公司', '动力电池组', '生产', '动力电池组']
# 当前行数: 4 当前内容: ['湖北回天新材料股份有限公司', '动力电池组', '生产', '动力电池组']
# 当前行数: 5 当前内容: ['东风电子科技股份有限公司', '电机', '生产', '电机']
# 当前行数: 6 当前内容: ['精进电动科技股份有限公司', '电机', '生产', '电机']
# 当前行数: 7 当前内容: ['英飞特电子（杭州）股份有限公司', '电机', '生产', '电机']
# 当前行数: 8 当前内容: ['东风电子科技股份有限公司', '汽车电子', '生产', '汽车电子']
# 当前行数: 9 当前内容: ['浙江亚太机电股份有限公司', '汽车电子', '生产', '汽车电子']
# 当前行数: 10 当前内容: ['沪士电子股份有限公司', '汽车电子', '生产', '汽车电子']
# 当前行数: 11 当前内容: ['镇江东方电热科技股份有限公司', '电控', '生产', '电控']
# 当前行数: 12 当前内容: ['江苏东方电热器制造有限公司', '电控', '生产', '电控']
# 当前行数: 13 当前内容: ['云度新能源汽车有限公司', '电控', '生产', '电控']
